0), AccelEntry(timestamp=5.9975936E8, x=-958.0, y=-84.0, z=143.0), AccelEntry(timestamp=5.9975936E8, x=-958.0, y=-85.0, z=138.0), AccelEntry(timestamp=5.9975936E8, x=-951.0, y=-84.0, z=138.0), AccelEntry(timestamp=5.9975936E8, x=-949.0, y=-85.0, z=140.0), AccelEntry(timestamp=5.9975936E8, x=-940.0, y=-82.0, z=141.0), AccelEntry(timestamp=5.9975936E8, x=-940.0, y=-84.0, z=143.0), AccelEntry(timestamp=5.9975936E8, x=-941.0, y=-81.0, z=143.0), AccelEntry(timestamp=5.9975936E8, x=-936.0, y=-83.0, z=150.0), AccelEntry(timestamp=5.9975936E8, x=-937.0, y=-81.0, z=154.0), AccelEntry(timestamp=5.9975936E8, x=-938.0, y=-82.0, z=157.0), AccelEntry(timestamp=5.9975936E8, x=-939.0, y=-82.0, z=164.0), AccelEntry(timestamp=5.9975936E8, x=-939.0, y=-84.0, z=164.0), AccelEntry(timestamp=5.9975936E8, x=-943.0, y=-83.0, z=161.0), AccelEntry(timestamp=5.9975936E8, x=-948.0, y=-81.0, z=166.0), AccelEntry(timestamp=5.9975936E8, x=-945.0, y=-84.0, z=159.0), AccelEntry(timestamp=5.9975936E8, x=-949.0, y=-83.0, z=157.0), AccelEntry(timestamp=5.9975936E8, x=-950.0, y=-83.0, z=156.0), AccelEntry(timestamp=5.9975936E8, x=-953.0, y=-86.0, z=155.0), AccelEntry(timestamp=5.9975936E8, x=-944.0, y=-85.0, z=156.0), AccelEntry(timestamp=5.9975936E8, x=-949.0, y=-83.0, z=155.0), AccelEntry(timestamp=5.9975936E8, x=-949.0, y=-86.0, z=155.0), AccelEntry(timestamp=5.9975936E8, x=-950.0, y=-84.0, z=155.0), AccelEntry(timestamp=5.9975936E8, x=-945.0, y=-82.0, z=153.0), AccelEntry(timestamp=5.9975936E8, x=-942.0, y=-83.0, z=153.0), AccelEntry(timestamp=5.9975936E8, x=-943.0, y=-83.0, z=156.0), AccelEntry(timestamp=5.9975936E8, x=-944.0, y=-84.0, z=157.0), AccelEntry(timestamp=5.9975936E8, x=-944.0, y=-84.0, z=155.0), AccelEntry(timestamp=5.9975936E8, x=-942.0, y=-85.0, z=154.0)]"
raw = raw.replace("AccelEntry", "").replace("(", "{").replace(")", "}").replace("timestamp=", "'timestamp': ").replace("x=", "'x': ").replace("y=", "'y': ").replace("z=", "'z': ")

values = ast.literal_eval(raw)
values
# Out:
# [{'timestamp': 599759360.0, 'x': -904.0, 'y': 117.0, 'z': 257.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 124.0, 'z': 256.0},
#  {'timestamp': 599759360.0, 'x': -904.0, 'y': 120.0, 'z': 255.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 120.0, 'z': 256.0},
#  {'timestamp': 599759360.0, 'x': -906.0, 'y': 123.0, 'z': 254.0},
#  {'timestamp': 599759360.0, 'x': -904.0, 'y': 124.0, 'z': 256.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 123.0, 'z': 255.0},
#  {'timestamp': 599759360.0, 'x': -904.0, 'y': 124.0, 'z': 257.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 123.0, 'z': 255.0},
#  {'timestamp': 599759360.0, 'x': -904.0, 'y': 126.0, 'z': 257.0},
#  {'timestamp': 599759360.0, 'x': -904.0, 'y': 125.0, 'z': 256.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 124.0, 'z': 253.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 124.0, 'z': 257.0},
#  {'timestamp': 599759360.0, 'x': -905.0, 'y': 122.0, 'z': 255.0},
# ...

# %%
import ast
import matplotlib.pyplot as plt

# Assuming `values` is already defined and contains the accelerometer data
#limit = len(values)
limit = 1000

# Extract x, y, and z values
timestamp_values = [entry['timestamp'] for entry in values][:limit]
new_array = list(range(len(timestamp_values)))
x_values = [entry['x'] for entry in values][:limit]
y_values = [entry['y'] for entry in values][:limit]
z_values = [entry['z'] for entry in values][:limit]

# Plot x values
plt.figure(figsize=(10, 5))
plt.plot(new_array, x_values, linewidth=0.5, color='blue', label='x values')
plt.title('Graph of x Values')
plt.xlabel('Index')
plt.ylabel('x')
plt.grid(True)
plt.legend()
plt.show()

# Plot y values
plt.figure(figsize=(10, 5))
plt.plot(new_array, y_values, linewidth=0.5, color='green', label='y values')
plt.title('Graph of y Values')
plt.xlabel('Index')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# Plot z values
plt.figure(figsize=(10, 5))
plt.plot(new_array, z_values, linewidth=0.5, color='red', label='z values')
plt.title('Graph of z Values')
plt.xlabel('Index')
plt.ylabel('z')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import ast
import matplotlib.pyplot as plt
from sklearn.decomposition import FastICA

limit = 1000
# Assuming `values` is already defined and contains the accelerometer data
x_values = [entry['x'] for entry in values][:limit]
y_values = [entry['y'] for entry in values][:limit]
z_values = [entry['z'] for entry in values][:limit]

# Stack the signals into a matrix
signals = np.vstack((x_values, z_values)).T

# Apply ICA
ica = FastICA(n_components=2)
components = ica.fit_transform(signals)

# Plot the independent components
plt.figure(figsize=(10, 7))
for i, component in enumerate(components.T):
    plt.subplot(2, 1, i + 1)
    plt.plot(component)
    plt.title(f'Independent Component {i + 1}')
plt.tight_layout()
plt.show()

# Assuming the heart beat signal is in the first component (this may vary)
# Remove the heart beat component by setting it to zero
components[:, 0] = 0

# Reconstruct the signals without the heart beat component
filtered_signals = ica.inverse_transform(components)

# Extract the filtered x, y, and z values
filtered_x_values = filtered_signals[:, 0]
filtered_y_values = filtered_signals[:, 1]
filtered_z_values = filtered_signals[:, 2]

# Plot the filtered signals
plt.figure(figsize=(10, 5))
# plt.plot(filtered_x_values, label='Filtered x values', color='blue')
# plt.plot(filtered_y_values, label='Filtered y values', color='green')
plt.plot(z_values, linewidth=0.5, color='green', label='z values')
plt.plot(filtered_z_values, label='Filtered z values', color='red', linewidth=0.5, alpha=0.3)
plt.title('Filtered Accelerometer Signals')
plt.xlabel('Index')
plt.ylabel('Values')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 38
#      36 filtered_x_values = filtered_signals[:, 0]
#      37 filtered_y_values = filtered_signals[:, 1]
# ---> 38 filtered_z_values = filtered_signals[:, 2]
#      40 # Plot the filtered signals
#      41 plt.figure(figsize=(10, 5))
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import resample

# Assuming `values` is already defined and contains the accelerometer data
limit = len(values)
x_values = [entry['x'] for entry in values][:limit]
y_values = [entry['y'] for entry in values][:limit]
z_values = [entry['z'] for entry in values][:limit]

# Define a function to compute the moving average
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')

# Resample the data
window_size = 50  # Adjust the window size for more or less smoothing
downsample_factor = 40  # Adjust the downsample factor to reduce the frequency

smoothed_z_values = moving_average(z_values, window_size)
new_sample_count = len(smoothed_z_values) // downsample_factor  # Adjust the factor to change the resampling rate
resampled_z_values = resample(smoothed_z_values, new_sample_count)

# Create a new x-axis for the resampled data
resampled_x_values = np.linspace(0, len(z_values), new_sample_count)

# Plot the original and resampled z values
plt.figure(figsize=(10, 5))
plt.plot(range(len(z_values)), z_values, linewidth=0.5, color='green', label='Original z values', alpha=0.1)
plt.plot(resampled_x_values, resampled_z_values, linewidth=0.5, color='red', label='Resampled z values', alpha=1)
plt.title('Original and Resampled Graph of z Values')
plt.xlabel('Index')
plt.ylabel('z')
plt.grid(True)
plt.legend()
plt.show()

# %%
len(resampled_x_values), len(z_values)
# Out:
# (123, 4999)
