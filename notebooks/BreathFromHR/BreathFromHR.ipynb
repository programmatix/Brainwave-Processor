# %%
import ast

raw = "[FloatEntry(x=159.0, y=68.0), FloatEntry(x=160.0, y=68.0), FloatEntry(x=161.0, y=68.0), FloatEntry(x=162.0, y=68.0), FloatEntry(x=162.0, y=68.0), FloatEntry(x=164.0, y=69.0), FloatEntry(x=164.0, y=69.0), FloatEntry(x=166.0, y=70.0), FloatEntry(x=166.0, y=70.0), FloatEntry(x=168.0, y=69.0), FloatEntry(x=169.0, y=70.0), FloatEntry(x=170.0, y=71.0), FloatEntry(x=170.0, y=72.0), FloatEntry(x=172.0, y=73.0), FloatEntry(x=173.0, y=73.0), FloatEntry(x=174.0, y=73.0), FloatEntry(x=175.0, y=74.0), FloatEntry(x=176.0, y=75.0), FloatEntry(x=177.0, y=76.0), FloatEntry(x=178.0, y=76.0), FloatEntry(x=179.0, y=77.0), FloatEntry(x=180.0, y=76.0), FloatEntry(x=181.0, y=75.0), FloatEntry(x=182.0, y=73.0), FloatEntry(x=183.0, y=72.0), FloatEntry(x=184.0, y=72.0), FloatEntry(x=185.0, y=72.0), FloatEntry(x=186.0, y=72.0), FloatEntry(x=187.0, y=72.0), FloatEntry(x=188.0, y=72.0), FloatEntry(x=189.0, y=72.0), FloatEntry(x=190.0, y=71.0), FloatEntry(x=191.0, y=71.0), FloatEntry(x=191.0, y=70.0), FloatEntry(x=193.0, y=70.0), FloatEntry(x=193.0, y=69.0), FloatEntry(x=195.0, y=70.0), FloatEntry(x=195.0, y=70.0), FloatEntry(x=197.0, y=71.0), FloatEntry(x=198.0, y=72.0), FloatEntry(x=199.0, y=72.0), FloatEntry(x=199.0, y=71.0), FloatEntry(x=201.0, y=70.0), FloatEntry(x=201.0, y=70.0), FloatEntry(x=203.0, y=70.0), FloatEntry(x=203.0, y=70.0), FloatEntry(x=205.0, y=71.0), FloatEntry(x=206.0, y=71.0), FloatEntry(x=207.0, y=72.0), FloatEntry(x=207.0, y=72.0), FloatEntry(x=209.0, y=71.0), FloatEntry(x=209.0, y=71.0), FloatEntry(x=211.0, y=70.0), FloatEntry(x=212.0, y=70.0), FloatEntry(x=213.0, y=71.0), FloatEntry(x=214.0, y=71.0), FloatEntry(x=215.0, y=71.0), FloatEntry(x=216.0, y=71.0), FloatEntry(x=217.0, y=71.0), FloatEntry(x=218.0, y=70.0), FloatEntry(x=219.0, y=69.0), FloatEntry(x=220.0, y=69.0), FloatEntry(x=221.0, y=68.0), FloatEntry(x=222.0, y=68.0), FloatEntry(x=223.0, y=68.0), FloatEntry(x=224.0, y=68.0), FloatEntry(x=225.0, y=68.0), FloatEntry(x=226.0, y=68.0), FloatEntry(x=227.0, y=69.0), FloatEntry(x=228.0, y=70.0), FloatEntry(x=229.0, y=70.0), FloatEntry(x=230.0, y=71.0), FloatEntry(x=231.0, y=71.0), FloatEntry(x=232.0, y=71.0), FloatEntry(x=233.0, y=71.0), FloatEntry(x=234.0, y=71.0), FloatEntry(x=235.0, y=71.0), FloatEntry(x=236.0, y=72.0), FloatEntry(x=236.0, y=72.0), FloatEntry(x=238.0, y=73.0), FloatEntry(x=238.0, y=74.0), FloatEntry(x=240.0, y=74.0), FloatEntry(x=240.0, y=74.0), FloatEntry(x=242.0, y=74.0), FloatEntry(x=243.0, y=74.0), FloatEntry(x=244.0, y=74.0), FloatEntry(x=244.0, y=72.0), FloatEntry(x=246.0, y=71.0), FloatEntry(x=246.0, y=71.0), FloatEntry(x=248.0, y=71.0), FloatEntry(x=248.0, y=71.0), FloatEntry(x=250.0, y=72.0), FloatEntry(x=250.0, y=73.0), FloatEntry(x=252.0, y=73.0), FloatEntry(x=253.0, y=73.0), FloatEntry(x=254.0, y=73.0), FloatEntry(x=255.0, y=73.0), FloatEntry(x=256.0, y=72.0), FloatEntry(x=257.0, y=72.0), FloatEntry(x=258.0, y=72.0), FloatEntry(x=259.0, y=72.0), FloatEntry(x=260.0, y=73.0), FloatEntry(x=261.0, y=74.0), FloatEntry(x=262.0, y=77.0), FloatEntry(x=263.0, y=78.0), FloatEntry(x=264.0, y=79.0), FloatEntry(x=265.0, y=81.0), FloatEntry(x=266.0, y=81.0), FloatEntry(x=267.0, y=81.0), FloatEntry(x=268.0, y=81.0), FloatEntry(x=269.0, y=80.0), FloatEntry(x=270.0, y=80.0), FloatEntry(x=271.0, y=79.0), FloatEntry(x=272.0, y=79.0), FloatEntry(x=273.0, y=78.0), FloatEntry(x=274.0, y=78.0), FloatEntry(x=275.0, y=79.0), FloatEntry(x=276.0, y=81.0), FloatEntry(x=277.0, y=83.0), FloatEntry(x=278.0, y=83.0), FloatEntry(x=279.0, y=83.0), FloatEntry(x=279.0, y=82.0)]"
raw = raw.replace("FloatEntry", "").replace("(", "{").replace(")", "}").replace("x=", "'x': ").replace("y=", "'y': ")

values = ast.literal_eval(raw)
values
# Out:
# [{'x': 159.0, 'y': 68.0},
#  {'x': 160.0, 'y': 68.0},
#  {'x': 161.0, 'y': 68.0},
#  {'x': 162.0, 'y': 68.0},
#  {'x': 162.0, 'y': 68.0},
#  {'x': 164.0, 'y': 69.0},
#  {'x': 164.0, 'y': 69.0},
#  {'x': 166.0, 'y': 70.0},
#  {'x': 166.0, 'y': 70.0},
#  {'x': 168.0, 'y': 69.0},
#  {'x': 169.0, 'y': 70.0},
#  {'x': 170.0, 'y': 71.0},
#  {'x': 170.0, 'y': 72.0},
#  {'x': 172.0, 'y': 73.0},
#  {'x': 173.0, 'y': 73.0},
#  {'x': 174.0, 'y': 73.0},
#  {'x': 175.0, 'y': 74.0},
#  {'x': 176.0, 'y': 75.0},
#  {'x': 177.0, 'y': 76.0},
#  {'x': 178.0, 'y': 76.0},
#  {'x': 179.0, 'y': 77.0},
#  {'x': 180.0, 'y': 76.0},
#  {'x': 181.0, 'y': 75.0},
#  {'x': 182.0, 'y': 73.0},
#  {'x': 183.0, 'y': 72.0},
#  {'x': 184.0, 'y': 72.0},
#  {'x': 185.0, 'y': 72.0},
#  {'x': 186.0, 'y': 72.0},
#  {'x': 187.0, 'y': 72.0},
#  {'x': 188.0, 'y': 72.0},
#  {'x': 189.0, 'y': 72.0},
#  {'x': 190.0, 'y': 71.0},
#  {'x': 191.0, 'y': 71.0},
#  {'x': 191.0, 'y': 70.0},
#  {'x': 193.0, 'y': 70.0},
# ...

# %%
import ast
import matplotlib.pyplot as plt

# Extract x and y values
x_values = [entry['x'] for entry in values]
y_values = [entry['y'] for entry in values]

# Plot the values
plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, marker='o')
plt.title('Graph of FloatEntry Values')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
# Extract x and y values
x_values = [entry['x'] for entry in values]
y_values = [entry['y'] for entry in values]

# Naive peak detection
peaks = []
for i in range(1, len(y_values) - 2):
    if y_values[i - 1] < y_values[i] >= y_values[i + 2]:
        peaks.append((x_values[i], y_values[i]))

import ast
import matplotlib.pyplot as plt


# Plot the values and peaks
plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, marker='o', label='Values', alpha=0.2)
plt.scatter(*zip(*peaks), color='red', label='Peaks')
plt.title('Graph of FloatEntry Values with Naive Peak Detection')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# Print detected peaks
print("Detected peaks:", peaks)
# Out:
# Detected peaks: [(166.0, 70.0), (172.0, 73.0), (179.0, 77.0), (198.0, 72.0), (207.0, 72.0), (213.0, 71.0), (230.0, 71.0), (238.0, 74.0), (250.0, 73.0), (265.0, 81.0), (277.0, 83.0)]

# %%
# Out:
# Detected peaks: [(164.0, 69.0), (166.0, 70.0), (169.0, 70.0), (170.0, 71.0), (170.0, 72.0), (172.0, 73.0), (175.0, 74.0), (176.0, 75.0), (177.0, 76.0), (179.0, 77.0), (195.0, 70.0), (197.0, 71.0), (198.0, 72.0), (205.0, 71.0), (207.0, 72.0), (213.0, 71.0), (227.0, 69.0), (228.0, 70.0), (230.0, 71.0), (236.0, 72.0), (238.0, 73.0), (238.0, 74.0), (250.0, 72.0), (250.0, 73.0), (260.0, 73.0), (261.0, 74.0), (262.0, 77.0), (263.0, 78.0), (264.0, 79.0), (265.0, 81.0), (275.0, 79.0), (276.0, 81.0), (277.0, 83.0)]
